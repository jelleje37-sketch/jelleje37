# %% [markdown]
# # 3️⃣ Visualizations
#
# ## Objective
# - Create compelling visualizations
# - Tell the data story
# - Support key findings with visual evidence
# - Prepare charts for executive dashboard

# %% [markdown]
# ## Import Libraries & Load Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as go

# Load data
df = pd.read_csv('../data/processed/[cleaned_dataset].csv')

# Set style
sns.set_palette('husl')
plt.rcParams['figure.figsize'] = (14, 8)

# %% [markdown]
# ## Visualization 1: [Chart Title - e.g., Distribution by Category]

# %%
# Static version (Matplotlib)
plt.figure(figsize=(10, 6))
# [Add your plotting code]
# Example:
# df.groupby('category')['metric'].count().plot(kind='bar', color='steelblue')
# plt.title('[Chart Title]')
# plt.xlabel('[X Label]')
# plt.ylabel('[Y Label]')
plt.tight_layout()
plt.savefig('../images/visualization_1.png', dpi=300, bbox_inches='tight')
plt.show()

print('Chart saved to images/')

# %%
# Interactive version (Plotly)
# fig = px.bar(df.groupby('category')['metric'].count().reset_index(), 
#              x='category', y='metric',
#              title='[Chart Title]')
# fig.show()

# %% [markdown]
# ## Visualization 2: [Chart Title - e.g., Trend Over Time]

# %%
# Time series plot
# [Add your plotting code]
# Example:
# df_trend = df.groupby('date')['metric'].agg(['mean', 'count'])
# plt.plot(df_trend.index, df_trend['mean'], marker='o', linewidth=2)
# plt.title('[Chart Title]')
# plt.xlabel('Date')
# plt.ylabel('Metric')
# plt.xticks(rotation=45)
plt.tight_layout()
plt.savefig('../images/visualization_2.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Visualization 3: [Chart Title - e.g., Relationship/Correlation]

# %%
# Scatter or heatmap
# [Add your plotting code]
# Example for scatter:
# plt.scatter(df['variable1'], df['variable2'], alpha=0.6, s=50)
# plt.title('[Chart Title]')
# plt.xlabel('[X Var]')
# plt.ylabel('[Y Var]')

# Example for heatmap:
# corr_matrix = df.corr()
# sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', center=0)
# plt.title('[Correlation Matrix]')

plt.tight_layout()
plt.savefig('../images/visualization_3.png', dpi=300, bbox_inches='tight')
plt.show()

# %% [markdown]
# ## Executive Dashboard Summary

# %%
# Create a multi-panel dashboard summary
fig, axes = plt.subplots(2, 2, figsize=(16, 12))

# Panel 1
axes[0, 0].text(0.5, 0.5, 'KPI 1: [Metric Name]\n[Value]', 
                ha='center', va='center', fontsize=16, weight='bold')
axes[0, 0].set_xlim(0, 1)
axes[0, 0].set_ylim(0, 1)
axes[0, 0].axis('off')

# Panel 2
axes[0, 1].text(0.5, 0.5, 'KPI 2: [Metric Name]\n[Value]', 
                ha='center', va='center', fontsize=16, weight='bold')
axes[0, 1].set_xlim(0, 1)
axes[0, 1].set_ylim(0, 1)
axes[0, 1].axis('off')

# Panel 3: Chart
# Add visualization code here
axes[1, 0].set_title('[Chart for Bottom Left]')

# Panel 4: Chart
# Add visualization code here
axes[1, 1].set_title('[Chart for Bottom Right]')

plt.suptitle('Executive Dashboard Summary', fontsize=18, weight='bold')
plt.tight_layout()
plt.savefig('../images/dashboard_main.png', dpi=300, bbox_inches='tight')
plt.show()

print('Dashboard saved!')

# %% [markdown]
# ## Summary
#
# All visualizations have been created and saved to `images/` folder. Ready for Tableau integration or presentation!
