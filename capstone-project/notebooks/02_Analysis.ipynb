# %% [markdown]
# # 2️⃣ Analysis
#
# ## Objective
# - Answer business questions
# - Identify key patterns and trends
# - Perform statistical analysis
# - Generate insights for recommendations

# %% [markdown]
# ## Import Libraries & Load Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats

# Load cleaned data
df = pd.read_csv('../data/processed/[cleaned_dataset].csv')
print(f'Data loaded: {df.shape[0]} rows × {df.shape[1]} columns')

# %% [markdown]
# ## Question 1: [Business Question 1]

# %%
# Analysis for Question 1
# [Add your analysis code here]

# Example:
# grouped = df.groupby('category')['metric'].agg(['count', 'mean', 'median'])
# print(grouped)

# KEY INSIGHT: [Document your finding]
print('\n[Insight summary here]')

# %%
# Visualization for Question 1
# [Add your visualization code here]
plt.show()

# %% [markdown]
# ## Question 2: [Business Question 2]

# %%
# Analysis for Question 2
# [Add your analysis code here]

# KEY INSIGHT: [Document your finding]
print('\n[Insight summary here]')

# %%
# Visualization for Question 2
# [Add your visualization code here]
plt.show()

# %% [markdown]
# ## Question 3: [Business Question 3]

# %%
# Analysis for Question 3
# [Add your analysis code here]

# KEY INSIGHT: [Document your finding]
print('\n[Insight summary here]')

# %%
# Visualization for Question 3
# [Add your visualization code here]
plt.show()

# %% [markdown]
# ## Statistical Testing (Optional)

# %%
# Correlation Analysis
# correlation_matrix = df.corr()
# sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
# plt.show()

# T-Test Example
# group1 = df[df['category'] == 'A']['metric']
# group2 = df[df['category'] == 'B']['metric']
# t_stat, p_value = stats.ttest_ind(group1, group2)
# print(f'T-statistic: {t_stat}, P-value: {p_value}')

print('Add statistical tests as needed')

# %% [markdown]
# ## Key Findings Summary

# %%
findings = {
    'Finding 1': '[Description and metric]',
    'Finding 2': '[Description and metric]',
    'Finding 3': '[Description and metric]',
    'Finding 4': '[Description and metric]'
}

print('\n=== KEY FINDINGS ===')
for key, value in findings.items():
    print(f'{key}: {value}')
